# %%
from IPython.display import Image
import glob
import os

# %%
# %cd ..
# Out:
# /home/kuba/Projects/deeplearning_image_pixelwise

# %%
DATA_DIR = 'data'
VAL_DIR = os.path.join(DATA_DIR, 'images', 'val2017')
VAL_ANNOT_DIR = os.path.join(DATA_DIR, 'masks', 'val2017')

# %%
val_image_paths = glob.glob(os.path.join(VAL_DIR, '**'))
val_annotation_image_paths = glob.glob(os.path.join(VAL_ANNOT_DIR, '**'))

# %%
example_image = val_image_paths[0]
example_image_filename = os.path.basename(example_image)

# %%
print(example_image)
Image(example_image)
# Out:
# data/images/val2017/000000217957.jpg

# %%
print(val_annotation_image_paths[0])
Image(val_annotation_image_paths[0])
# Out:
# data/masks/val2017/000000114884.png
